# %% [markdown]
# # Principal Component Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import urllib.request
import zipfile

# %%
data = pd.read_table('ex7data1.txt', sep=',', header=None, dtype=np.float32)
data
# Out:
#            0         1
# 0   3.381563  3.389113
# 1   4.527875  5.854178
# 2   2.655682  4.411995
# 3   2.765235  3.715414
# 4   2.846560  4.175507
# 5   3.890672  6.488381
# 6   3.475805  3.632849
# 7   5.911298  6.680768
# 8   3.928894  5.098447
# 9   4.561835  5.623299
# 10  4.574072  5.397651
# 11  4.371734  5.461165
# 12  4.191694  4.954694
# 13  5.244085  4.661488
# 14  2.835840  3.768017
# 15  5.635270  6.312114
# 16  4.686330  5.665241
# 17  2.850513  4.626456
# 18  5.110157  7.363197
# 19  5.182564  4.646509
# 20  5.707328  6.681040
# 21  3.579684  4.802781
# 22  5.639378  6.120436
# 23  4.263469  4.689429
# 24  2.536517  3.884491
# 25  3.223829  4.942556
# 26  4.929488  5.955019
# 27  5.792958  5.108393
# 28  2.816848  4.818958
# 29  3.888824  5.100366
# 30  3.343234  5.893013
# 31  5.879734  5.521417
# 32  3.103919  3.857102
# 33  5.331506  4.680742
# 34  3.375427  4.565379
# 35  4.776679  6.254350
# 36  2.675746  3.730970
# 37  5.500277  5.679481
# 38  1.797097  3.247539
# ...

# %%
X_train = data.values

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.axis([0.5, 6.5, 2, 8])
ax.plot(X_train[:,0], X_train[:,1], marker='.', color='#0F00FF', markersize=10, linestyle='')

# %%
model = PCA(n_components=1)

model.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=1, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
model.components_
# Out:
# array([[-0.7690814 , -0.63915086]], dtype=float32)

# %%
X_red = model.transform(X_train)
X_red
# Out:
# array([[ 1.4987656 ],
#        [-0.9583908 ],
#        [ 1.403251  ],
#        [ 1.7642164 ],
#        [ 1.4076018 ],
#        [-0.8736808 ],
#        [ 1.2705013 ],
#        [-2.5506716 ],
#        [-0.01469915],
#        [-0.83694226],
#        [-0.70212984],
#        [-0.58711076],
#        [-0.12493365],
#        [-0.7469054 ],
#        [ 1.6762936 ],
#        [-2.1027575 ],
#        [-0.9594961 ],
#        [ 1.1163366 ],
#        [-2.3707037 ],
#        [-0.69001687],
#        [-2.3939755 ],
#        [ 0.44284672],
#        [-1.9834054 ],
#        [-0.01059009],
#        [ 1.8320533 ],
#        [ 0.62719107],
#        [-1.3317167 ],
#        [-1.454673  ],
#        [ 1.0191902 ],
#        [ 0.01489142],
#        [-0.07212707],
#        [-1.7853954 ],
#        [ 1.4131801 ],
#        [-0.82644546],
#        [ 0.7516732 ],
#        [-1.4055114 ],
#        [ 1.8230976 ],
#        [-1.5945888 ],
#        [ 2.8078358 ],
#        [-0.3255155 ],
#        [-0.9857883 ],
# ...

# %%
X_pred = model.inverse_transform(X_red)
X_pred
# Out:
# array([[2.836592 , 4.0448685],
#        [4.726345 , 5.615362 ],
#        [2.9100504, 4.1059165],
#        [2.6324387, 3.8752053],
#        [2.9067044, 4.1031356],
#        [4.661196 , 5.5612197],
#        [3.0121458, 4.190764 ],
#        [5.9509387, 6.6330695],
#        [4.0005693, 5.012201 ],
#        [4.6329412, 5.537738 ],
#        [4.5292597, 5.4515724],
#        [4.4408007, 5.378058 ],
#        [4.085349 , 5.0826573],
#        [4.563696 , 5.4801908],
#        [2.7000585, 3.9314013],
#        [5.6064563, 6.346785 ],
#        [4.7271953, 5.6160684],
#        [3.130711 , 4.289298 ],
#        [5.8125286, 6.518043 ],
#        [4.5199437, 5.4438305],
#        [5.8304267, 6.532917 ],
#        [3.6486795, 4.71976  ],
#        [5.5146646, 6.270501 ],
#        [3.9974093, 5.0095744],
#        [2.5802665, 3.8318472],
#        [3.5069036, 4.601936 ],
#        [5.013463 , 5.8539734],
#        [5.1080265, 5.9325614],
#        [3.2054245, 4.3513894],
#        [3.977812 , 4.993288 ],
# ...

# %%
X_train
# Out:
# array([[3.3815627, 3.3891127],
#        [4.5278754, 5.854178 ],
#        [2.6556818, 4.411995 ],
#        [2.7652347, 3.7154136],
#        [2.84656  , 4.1755066],
#        [3.890672 , 6.488381 ],
#        [3.4758053, 3.6328487],
#        [5.9112983, 6.6807685],
#        [3.928894 , 5.098447 ],
#        [4.5618353, 5.623299 ],
#        [4.574072 , 5.3976507],
#        [4.3717337, 5.4611654],
#        [4.191694 , 4.954694 ],
#        [5.2440853, 4.6614876],
#        [2.8358402, 3.768017 ],
#        [5.6352696, 6.3121142],
#        [4.68633  , 5.6652412],
#        [2.8505135, 4.6264563],
#        [5.1101575, 7.363197 ],
#        [5.182564 , 4.646509 ],
#        [5.7073283, 6.68104  ],
#        [3.5796845, 4.8027806],
#        [5.6393776, 6.1204357],
#        [4.2634687, 4.689429 ],
#        [2.536517 , 3.8844907],
#        [3.223829 , 4.942556 ],
#        [4.929488 , 5.9550195],
#        [5.792958 , 5.108393 ],
#        [2.8168483, 4.818958 ],
#        [3.8888242, 5.1003656],
# ...

# %%
np.mean(np.sum(np.square(X_train-X_pred), axis=1))
# Out:
# 0.3072608

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.axis([0.5, 6.5, 2, 8])
ax.plot(X_train[:,0], X_train[:,1], marker='.', color='#0F00FF', markersize=10, linestyle='') 
ax.plot(X_pred[:,0], X_pred[:,1], marker='.', color='#FF00AE', markersize=10)

# %% [markdown]
# -----

# %%
url = 'https://firebasestorage.googleapis.com/v0/b/z2tma61d2a74hya815w9x621uszb3a.appspot.com/o/ex7faces.txt.zip?alt=media&token=a70a9581-aeed-4be5-af6e-b21bfa620b87'
local_zip = 'ex7faces.txt.zip'
urllib.request.urlretrieve(url, local_zip)
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall()
zip_ref.close()

# %%
data = pd.read_table('ex7faces.txt', sep=',', header=None, dtype=np.float32)
data
# Out:
#             0           1           2           3           4          5     \
# 0     -37.866314  -45.866314  -53.866314  -51.866314  -40.866314 -33.866314
# 1       8.133686   -0.866314   -8.866314  -15.866314  -17.866314 -16.866314
# 2     -32.866314  -34.866314  -36.866314  -18.866314    6.133686  15.133686
# 3     -84.866310  -64.866310  -47.866314  -42.866314  -38.866314 -28.866314
# 4       2.133686    6.133686    5.133686    9.133686   10.133686  11.133686
# ...          ...         ...         ...         ...         ...        ...
# 4995   14.133686    9.133686   19.133686   18.133686   12.133686 -18.866314
# 4996  -61.866314  -64.866310  -64.866310  -68.866310  -71.866310 -74.866310
# 4997  -46.866314  -24.866314   -8.866314  -11.866314  -26.866314   3.133686
# 4998   19.133686   16.133686   14.133686   12.133686   10.133686  10.133686
# 4999 -108.866310 -106.866310 -102.866310 -103.866310 -101.866310 -97.866310
#
# ...

# %%
X_train = data.values

# %%
m,n = X_train[:100,:].shape
a = np.ceil(np.sqrt(n)).astype(int)
b = np.ceil(np.sqrt(m)).astype(int)
fig, axes = plt.subplots(figsize=(10,10),nrows=b, ncols=b, sharex=True, sharey=True)
fig.subplots_adjust(wspace=-0.01, hspace=-0.01)
for i in range(b):
    for j in range(b):
        img = np.rot90(np.fliplr(X_train[i*b+j,:].reshape((a,a))))
        axes[i,j].set_yticklabels([])
        axes[i,j].set_xticklabels([])
        axes[i,j].imshow(img,cmap='gray')

# %%
model = PCA(n_components=100)
model.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
model.components_
# Out:
# array([[-0.02044737, -0.02082927, -0.02088808, ..., -0.01429869,
#         -0.01279079, -0.01186198],
#        [ 0.04609064,  0.04794962,  0.04946635, ..., -0.04182157,
#         -0.03972975, -0.03786654],
#        [ 0.03992259,  0.04100449,  0.04327974, ...,  0.07918059,
#          0.07910304,  0.07711536],
#        ...,
#        [-0.03878117, -0.03245433, -0.02061564, ...,  0.03701414,
#         -0.0093057 , -0.03431779],
#        [-0.04671434, -0.02576855,  0.01450772, ...,  0.03305541,
#          0.01811401,  0.00289712],
#        [-0.05130754, -0.03971107, -0.03452344, ..., -0.00355468,
#          0.04550886,  0.07658836]], dtype=float32)

# %%
X_red = model.transform(X_train)
X_red
# Out:
# array([[ 621.322   , -242.66518 , -305.44067 , ...,  -33.416973,
#           36.50455 ,   37.760426],
#        [ 377.78973 ,  134.58626 , -264.7981  , ...,  -14.429716,
#          -11.778382,    2.689165],
#        [-301.8695  ,  251.17052 , -134.63564 , ...,  -19.819792,
#          -32.046837,  -26.495872],
#        ...,
#        [ 555.2193  , -496.8313  ,  810.52673 , ...,  -67.073395,
#           43.32338 ,    3.61771 ],
#        [1419.3582  ,  129.44077 ,   95.4426  , ...,  -21.249006,
#            6.112077,   13.139795],
#        [ 432.8735  , -111.71185 ,  220.77547 , ...,  -56.46734 ,
#           -4.290887,  -22.201544]], dtype=float32)

# %%
X_pred = model.inverse_transform(X_red)
X_pred
# Out:
# array([[ -42.692753  ,  -42.63755   ,  -42.221577  , ...,  -85.8152    ,
#          -71.38729   ,  -55.707607  ],
#        [  -5.6893005 ,   -4.6463356 ,   -5.779662  , ...,  -28.036596  ,
#           -9.950598  ,    0.70150757],
#        [ -31.80125   ,  -30.848034  ,  -26.023792  , ..., -109.063866  ,
#         -113.09534   , -111.82071   ],
#        ...,
#        [ -32.56832   ,  -29.424112  ,  -26.307377  , ...,   65.72847   ,
#           78.459946  ,   83.66893   ],
#        [   3.3676548 ,    9.116106  ,   16.48625   , ...,  -51.21229   ,
#          -41.950253  ,  -35.07164   ],
#        [-113.672806  , -115.03304   , -113.30863   , ...,   12.780554  ,
#           19.133469  ,   18.994602  ]], dtype=float32)

# %%
X_train
# Out:
# array([[ -37.866314  ,  -45.866314  ,  -53.866314  , ..., -110.86631   ,
#         -111.86631   ,  -99.86631   ],
#        [   8.133686  ,   -0.8663139 ,   -8.866314  , ...,  -34.866314  ,
#           -8.866314  ,    0.13368614],
#        [ -32.866314  ,  -34.866314  ,  -36.866314  , ..., -110.86631   ,
#         -111.86631   , -111.86631   ],
#        ...,
#        [ -46.866314  ,  -24.866314  ,   -8.866314  , ...,   90.13369   ,
#           80.13369   ,   59.133686  ],
#        [  19.133686  ,   16.133686  ,   14.133686  , ...,  -38.866314  ,
#          -41.866314  ,  -46.866314  ],
#        [-108.86631   , -106.86631   , -102.86631   , ...,   17.133686  ,
#           17.133686  ,   18.133686  ]], dtype=float32)

# %%
np.mean(np.sum(np.square(X_train-X_pred), axis=1))
# Out:
# 113544.34

# %%
m,n = X_pred[:100,:].shape
a = np.ceil(np.sqrt(n)).astype(int)
b = np.ceil(np.sqrt(m)).astype(int)
fig, axes = plt.subplots(figsize=(10,10),nrows=b, ncols=b, sharex=True, sharey=True)
fig.subplots_adjust(wspace=-0.01, hspace=-0.01)
for i in range(b):
    for j in range(b):
        img = np.rot90(np.fliplr(X_pred[i*b+j,:].reshape((a,a))))
        axes[i,j].set_yticklabels([])
        axes[i,j].set_xticklabels([])
        axes[i,j].imshow(img,cmap='gray')
